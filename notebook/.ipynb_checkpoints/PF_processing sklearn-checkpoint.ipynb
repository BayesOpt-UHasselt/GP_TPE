# %%
# import sys
# sys.path.append('../')

import numpy as np
import pandas as pd
from Hypervolume import HyperVolume
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

font = {'size': 16}
plt.rc('font', **font)

# %%
def plot_pf(non_dominated_points, rep, ax, l="", legend_uncertainty=True):
    
    m = non_dominated_points #np.mean(rep, axis=1)
    std =  np.sqrt(np.var(rep, axis=1))
    max_data = m+std #np.max(non_dominated_points, axis=1)
    min_data = m-std #np.min(non_dominated_points, axis=1)
    
    ells = [Ellipse(xy=[m[i,0], m[i,1]], 
                    width=np.abs(max_data[i,0]-min_data[i,0]), 
                    height=np.abs(max_data[i,1]-min_data[i,1]))
            for i in range(m.shape[0])]

    index = 0
    for e in ells:
        ax.add_patch(e)
        
        if index==0 and legend_uncertainty:
            e.set(clip_box=ax.bbox, alpha=0.2, facecolor="peachpuff", edgecolor='silver', label=r'Uncertainty ($mean \pm std$)')
        else:
            e.set(clip_box=ax.bbox, alpha=0.2, facecolor="peachpuff", edgecolor='silver')
        index+=1
        
#         e.set_edgecolor('silver')
#     max_axes = np.max([max_data[:,0], max_data[:,1]])
#     ax.set_xlim(0, max_axes+.5)
#     ax.set_ylim(0, max_axes+.5)

    ax.scatter(non_dominated_points[:, 0], non_dominated_points[:, 1], s=50, 
               label="Observed PF "+l)
    ax.set_xlabel("f1")
    ax.set_ylabel("f2")
    
#     ax.scatter(tf[:,0], tf[:,1], label="Optimal PF")
#     ax.scatter(solutions[:, 0], solutions[:, 1], color='orange', marker='+', zorder=len(ells)+2, label="Solutions")
    return ax

# %%
def compute_hypervolume(m, referencePoint):
    hv = HyperVolume(referencePoint)
    volume = hv.compute(m)
    return volume

# %%
def pareto_front(points, level=0, index=False):

    points = points.copy()
    ranks = np.zeros(len(points))
    r = 0
    c = len(points)
    while c > 0:
        extended = np.tile(points, (points.shape[0], 1, 1))
        dominance = np.sum(np.logical_and(
            np.all(extended <= np.swapaxes(extended, 0, 1), axis=2),
            np.any(extended < np.swapaxes(extended, 0, 1), axis=2)), axis=1)
        points[dominance == 0] = 1e9  # mark as used
        ranks[dominance == 0] = r
        r += 1
        c -= np.sum(dominance == 0)
    if index:
#         return ranks
        return [i for i in range(len(ranks)) if ranks[i] == level] 
    else:    
        ind = [i for i in range(len(ranks)) if ranks[i] == level]
        return points[ind]

# %%
def plot_hypervolumen(file_name, initial_point, gp, motpe, gp_motpe, ref_point):
    
    hv_gp = []
    hv_motpe = []
    hv_gp_motpe = []
    for index in range(initial_point, gp.shape[0]):
        pf = pareto_front(gp[:index], index=True)
        pf = gp[pf]
        volumen = compute_hypervolume(pf, ref_point)
        hv_gp.append(volumen)
        
        pf = pareto_front(motpe[:index], index=True)
        pf = motpe[pf]
        volumen = compute_hypervolume(pf, ref_point)
        hv_motpe.append(volumen)
        
        pf = pareto_front(gp_motpe[:index], index=True)
        pf = gp_motpe[pf]
        volumen = compute_hypervolume(pf, ref_point)
        hv_gp_motpe.append(volumen)
        
    print(file_name, hv_gp[-1], hv_motpe[-1], hv_gp_motpe[-1])
#     print(hv_gp)
    fig, ax = plt.subplots(figsize=(7,7))
    ax.plot(hv_gp, label="GP")
    ax.plot(hv_motpe, label="MOTPE")
    ax.plot(hv_gp_motpe, label="GP_MOTPE")
    ax.set_xlabel("Iterations (Number of infill points)")
    ax.set_ylabel("Hypervolumen")
    plt.legend(loc="lower right")
    plt.savefig(file_name, dpi=1200, bbox_inches='tight')

# %%
def plot_function(file_name, gp, motpe, gp_motpe, rgp, rmotpe, rgp_motpe, tpf=[], xlim=[0, 1], ylim=[0,1], plot_uncertainty=True):
    pf_gp = pareto_front(gp, index=True)
    rpf_gp = rgp[pf_gp]
    pf_gp = gp[pf_gp]
    
    pf_motpe = pareto_front(motpe, index=True)
    rpf_motpe = rmotpe[pf_motpe]
    pf_motpe = motpe[pf_motpe]
    
    pf_gp_motpe = pareto_front(gp_motpe, index=True)
    rpf_gp_motpe = rgp_motpe[pf_gp_motpe]
    pf_gp_motpe = gp_motpe[pf_gp_motpe]
    
    
    fig, ax = plt.subplots(figsize=(7,7))
    if len(tpf)!=0:
        ax.scatter(tpf[:,0], tpf[:,1], color='k', s=5, label="True PF")
    ax = plot_pf(pf_gp, rpf_gp, ax, l="GP", legend_uncertainty=plot_uncertainty)
    ax = plot_pf(pf_motpe, rpf_motpe, ax, l="MOTPE", legend_uncertainty=False)
    ax = plot_pf(pf_gp_motpe, rpf_gp_motpe, ax, l="GP_MOTPE", legend_uncertainty=False)
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.legend(loc='upper right')
    plt.savefig(file_name, dpi=1200, bbox_inches='tight')

# %%
# Load true PF
ZDT1 = pd.read_csv("PF_data\PF_functions\ZDT1.csv", sep=',', header=0).values
DTLZ6 = pd.read_csv("PF_data\PF_functions\DTLZ6.csv", sep=',', header=0).values
DTLZ7 = pd.read_csv("PF_data\PF_functions\DTLZ7.csv", sep=',', header=0).values
WFG4 = pd.read_csv("PF_data\PF_functions\WFG4.csv", sep=',', header=0).values

# %% [markdown]
# ## Pareto front visualization

# %%
# load data exploration
ZDT1_motpe = pd.read_csv("PF_data\exploration_noisy_MOTPE_ZDT1.csv", sep=',', header=0).values[:,1:]
DTLZ6_motpe = pd.read_csv("PF_data\exploration_noisy_MOTPE_DTLZ6.csv", sep=',', header=0).values[:,1:]
DTLZ7_motpe = pd.read_csv("PF_data\exploration_noisy_MOTPE_DTLZ7.csv", sep=',', header=0).values[:,1:]
WFG4_motpe = pd.read_csv("PF_data\exploration_noisy_MOTPE_WFG4.csv", sep=',', header=0).values[:,1:]

ZDT1_gp = pd.read_csv("PF_data\exploration_GP_ZDT1.csv", sep=',', header=0).values[:,1:]
DTLZ6_gp = pd.read_csv("PF_data\exploration_GP_DTLZ6.csv", sep=',', header=0).values[:,1:]
DTLZ7_gp = pd.read_csv("PF_data\exploration_GP_DTLZ7.csv", sep=',', header=0).values[:,1:]
WFG4_gp = pd.read_csv("PF_data\exploration_GP_WFG4.csv", sep=',', header=0).values[:,1:]

ZDT1_gp_motpe = pd.read_csv("PF_data\exploration_GP_MOTPE_ZDT1.csv", sep=',', header=0).values[:,1:]
DTLZ6_gp_motpe = pd.read_csv("PF_data\exploration_GP_MOTPE_DTLZ6.csv", sep=',', header=0).values[:,1:]
DTLZ7_gp_motpe = pd.read_csv("PF_data\exploration_GP_MOTPE_DTLZ7.csv", sep=',', header=0).values[:,1:]
WFG4_gp_motpe = pd.read_csv("PF_data\exploration_GP_MOTPE_WFG4.csv", sep=',', header=0).values[:,1:]


# load data replications
rZDT1_motpe = pd.read_csv("PF_data/replications_noisy_MOTPE_ZDT1.csv", sep=',', header=0).values[:,1:]
rZDT1_motpe = rZDT1_motpe.reshape((ZDT1_motpe.shape[0],
                        int(rZDT1_motpe.shape[0]/ZDT1_motpe.shape[0]), 
                         ZDT1_motpe.shape[1]))
rDTLZ6_motpe = pd.read_csv("PF_data/replications_noisy_MOTPE_DTLZ6.csv", sep=',', header=0).values[:,1:]
rDTLZ6_motpe = rDTLZ6_motpe.reshape((DTLZ6_motpe.shape[0],
                        int(rDTLZ6_motpe.shape[0]/DTLZ6_motpe.shape[0]), 
                         DTLZ6_motpe.shape[1]))
rDTLZ7_motpe = pd.read_csv("PF_data/replications_noisy_MOTPE_DTLZ7.csv", sep=',', header=0).values[:,1:]
rDTLZ7_motpe = rDTLZ7_motpe.reshape((DTLZ7_motpe.shape[0],
                        int(rDTLZ7_motpe.shape[0]/DTLZ7_motpe.shape[0]), 
                         DTLZ7_motpe.shape[1]))
rWFG4_motpe = pd.read_csv("PF_data/replications_noisy_MOTPE_WFG4.csv", sep=',', header=0).values[:,1:]
rWFG4_motpe = rWFG4_motpe.reshape((WFG4_motpe.shape[0],
                        int(rWFG4_motpe.shape[0]/WFG4_motpe.shape[0]), 
                         WFG4_motpe.shape[1]))

rZDT1_gp = pd.read_csv("PF_data/replications_GP_ZDT1.csv", sep=',', header=0).values[:,1:]
rZDT1_gp = rZDT1_gp.reshape((ZDT1_gp.shape[0],
                        int(rZDT1_gp.shape[0]/ZDT1_gp.shape[0]), 
                         ZDT1_gp.shape[1]))
rDTLZ6_gp = pd.read_csv("PF_data/replications_GP_DTLZ6.csv", sep=',', header=0).values[:,1:]
rDTLZ6_gp = rDTLZ6_gp.reshape((DTLZ6_gp.shape[0],
                        int(rDTLZ6_gp.shape[0]/DTLZ6_gp.shape[0]), 
                         DTLZ6_gp.shape[1]))
rDTLZ7_gp = pd.read_csv("PF_data/replications_GP_DTLZ7.csv", sep=',', header=0).values[:,1:]
rDTLZ7_gp = rDTLZ7_gp.reshape((DTLZ7_gp.shape[0],
                        int(rDTLZ7_gp.shape[0]/DTLZ7_gp.shape[0]), 
                         DTLZ7_gp.shape[1]))
rWFG4_gp = pd.read_csv("PF_data/replications_GP_WFG4.csv", sep=',', header=0).values[:,1:]
rWFG4_gp = rWFG4_gp.reshape((WFG4_gp.shape[0],
                        int(rWFG4_gp.shape[0]/WFG4_gp.shape[0]), 
                         WFG4_gp.shape[1]))

rZDT1_gp_motpe = pd.read_csv("PF_data/replications_GP_MOTPE_ZDT1.csv", sep=',', header=0).values[:,1:]
rZDT1_gp_motpe = rZDT1_gp_motpe.reshape((ZDT1_gp_motpe.shape[0],
                        int(rZDT1_gp_motpe.shape[0]/ZDT1_gp_motpe.shape[0]), 
                         ZDT1_gp_motpe.shape[1]))
rDTLZ6_gp_motpe = pd.read_csv("PF_data/replications_GP_MOTPE_DTLZ6.csv", sep=',', header=0).values[:,1:]
rDTLZ6_gp_motpe = rDTLZ6_gp_motpe.reshape((DTLZ6_gp_motpe.shape[0],
                        int(rDTLZ6_gp_motpe.shape[0]/DTLZ6_gp_motpe.shape[0]), 
                         DTLZ6_gp_motpe.shape[1]))
rDTLZ7_gp_motpe = pd.read_csv("PF_data/replications_GP_MOTPE_DTLZ7.csv", sep=',', header=0).values[:,1:]
rDTLZ7_gp_motpe = rDTLZ6_gp_motpe.reshape((DTLZ7_gp_motpe.shape[0],
                        int(rDTLZ7_gp_motpe.shape[0]/DTLZ7_gp_motpe.shape[0]), 
                         DTLZ7_gp_motpe.shape[1]))
rWFG4_gp_motpe = pd.read_csv("PF_data/replications_GP_MOTPE_WFG4.csv", sep=',', header=0).values[:,1:]
rWFG4_gp_motpe = rDTLZ6_gp_motpe.reshape((WFG4_gp_motpe.shape[0],
                        int(rWFG4_gp_motpe.shape[0]/WFG4_gp_motpe.shape[0]), 
                         WFG4_gp_motpe.shape[1]))

# %%
plot_function("pf_ZDT1.pdf",ZDT1_gp, ZDT1_motpe, ZDT1_gp_motpe,
              rZDT1_gp, rZDT1_motpe, rZDT1_gp_motpe, ZDT1, [0,1], [0,1])
plot_function("pf_DTLZ6.pdf", DTLZ6_gp, DTLZ6_motpe, DTLZ6_gp_motpe,
              rDTLZ6_gp, rDTLZ6_motpe, rDTLZ6_gp_motpe, DTLZ6, [0,5], [0,5])
plot_function("pf_DTLZ7.pdf", DTLZ7_gp, DTLZ7_motpe, DTLZ7_gp_motpe,
              rDTLZ7_gp, rDTLZ7_motpe, rDTLZ7_gp_motpe, DTLZ7, [0,1], [2,6])
plot_function("pf_WFG4.pdf", WFG4_gp, WFG4_motpe, WFG4_gp_motpe,
              rWFG4_gp, rWFG4_motpe, rWFG4_gp_motpe, WFG4, [0,3], [0,5.5])

# %% [markdown]
# ## Hypervolume history

# %%
initial_point = 54

plot_hypervolumen("hv_ZDT1.pdf", initial_point, ZDT1_gp, ZDT1_motpe, ZDT1_gp_motpe, [1, 10])
plot_hypervolumen("hv_DTLZ6.pdf", initial_point, DTLZ6_gp, DTLZ6_motpe, DTLZ6_gp_motpe, [10, 10])
plot_hypervolumen("hv_DTLZ7.pdf", initial_point, DTLZ7_gp, DTLZ7_motpe, DTLZ7_gp_motpe, [1, 23])
plot_hypervolumen("hv_WFG4.pdf", initial_point, WFG4_gp, WFG4_motpe, WFG4_gp_motpe, [3, 5])
# Out:
# hv_ZDT1.pdf 9.398659842677745 9.13581761666651 9.554011146719859
# hv_DTLZ6.pdf 88.16151495453526 91.78506165263504 90.1671634676278
# hv_DTLZ7.pdf 18.894934874932602 18.462372112119652 19.39682470552748
# hv_WFG4.pdf 6.698531935229314 7.960440060717553 7.422126605040488

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.scatter(WFG4_gp[:,0], WFG4_gp[:,1])

pf_gp = pareto_front(WFG4_gp, index=True)
pf_gp = WFG4_gp[pf_gp]
ax.scatter(pf_gp[:,0], pf_gp[:,1])

# %% [markdown]
# ## ML front

# %%
# load data exploration
ML_val_motpe = pd.read_csv("PF_data\ML\exploration_MOTPE_val_ML.csv", sep=',', header=0).values[:,1:]
ML_test_motpe = pd.read_csv("PF_data\ML\exploration_MOTPE_test_ML.csv", sep=',', header=0).values[:,1:]

ML_val_gp = pd.read_csv("PF_data\ML\exploration_GP_val_ML.csv", sep=',', header=0).values[:,1:]
ML_test_gp = pd.read_csv("PF_data\ML\exploration_GP_test_ML.csv", sep=',', header=0).values[:,1:]

ML_val_gp_motpe = pd.read_csv("PF_data\ML\exploration_GP_MOTPE_val_ML.csv", sep=',', header=0).values[:,1:]
ML_test_gp_motpe = pd.read_csv("PF_data\ML\exploration_GP_MOTPE_test_ML.csv", sep=',', header=0).values[:,1:]

# >>>>>>> SVM 
SVM_val_motpe = pd.read_csv("PF_data\ML\exploration_MOTPE_val_SVM.csv", sep=',', header=0).values[:,1:]
SVM_test_motpe = pd.read_csv("PF_data\ML\exploration_MOTPE_test_SVM.csv", sep=',', header=0).values[:,1:]

SVM_val_gp = pd.read_csv("PF_data\ML\exploration_GP_val_SVM.csv", sep=',', header=0).values[:,1:]
SVM_test_gp = pd.read_csv("PF_data\ML\exploration_GP_test_SVM.csv", sep=',', header=0).values[:,1:]

SVM_val_gp_motpe = pd.read_csv("PF_data\ML\exploration_GP_MOTPE_val_SVM.csv", sep=',', header=0).values[:,1:]
SVM_test_gp_motpe = pd.read_csv("PF_data\ML\exploration_GP_MOTPE_test_SVM.csv", sep=',', header=0).values[:,1:]

# >>>>>>> DT 
DT_val_motpe = pd.read_csv("PF_data\ML\exploration_MOTPE_val_DT.csv", sep=',', header=0).values[:,1:]
DT_test_motpe = pd.read_csv("PF_data\ML\exploration_MOTPE_test_DT.csv", sep=',', header=0).values[:,1:]

DT_val_gp = pd.read_csv("PF_data\ML\exploration_GP_val_DT.csv", sep=',', header=0).values[:,1:]
DT_test_gp = pd.read_csv("PF_data\ML\exploration_GP_test_DT.csv", sep=',', header=0).values[:,1:]

DT_val_gp_motpe = pd.read_csv("PF_data\ML\exploration_GP_MOTPE_val_DT.csv", sep=',', header=0).values[:,1:]
DT_test_gp_motpe = pd.read_csv("PF_data\ML\exploration_GP_MOTPE_test_DT.csv", sep=',', header=0).values[:,1:]

# load data replications
rML_motpe = pd.read_csv("PF_data/ML/replications_MOTPE_ML.csv", sep=',', header=0).values[:,1:]
rML_motpe = rML_motpe.reshape((ML_val_motpe.shape[0],
                        int(rML_motpe.shape[0]/ML_val_motpe.shape[0]), 
                         ML_val_motpe.shape[1]))

rML_gp = pd.read_csv("PF_data/ML/replications_GP_ML.csv", sep=',', header=0).values[:,1:]
rML_gp = rML_gp.reshape((ML_val_gp.shape[0],
                        int(rML_gp.shape[0]/ML_val_gp.shape[0]), 
                         ML_val_gp.shape[1]))

rML_gp_motpe = pd.read_csv("PF_data/ML/replications_GP_MOTPE_ML.csv", sep=',', header=0).values[:,1:]
rML_gp_motpe = rML_gp_motpe.reshape((ML_val_gp_motpe.shape[0],
                        int(rML_gp_motpe.shape[0]/ML_val_gp_motpe.shape[0]), 
                         ML_val_gp_motpe.shape[1]))

# >>>>> SVM
rSVM_motpe = pd.read_csv("PF_data/ML/replications_MOTPE_SVM.csv", sep=',', header=0).values[:,1:]
rSVM_motpe = rSVM_motpe.reshape((SVM_val_motpe.shape[0],
                        int(rSVM_motpe.shape[0]/SVM_val_motpe.shape[0]), 
                         SVM_val_motpe.shape[1]))

rSVM_gp = pd.read_csv("PF_data/ML/replications_GP_SVM.csv", sep=',', header=0).values[:,1:]
rSVM_gp = rSVM_gp.reshape((SVM_val_gp.shape[0],
                        int(rSVM_gp.shape[0]/SVM_val_gp.shape[0]), 
                         SVM_val_gp.shape[1]))

rSVM_gp_motpe = pd.read_csv("PF_data/ML/replications_GP_MOTPE_SVM.csv", sep=',', header=0).values[:,1:]
rSVM_gp_motpe = rSVM_gp_motpe.reshape((SVM_val_gp_motpe.shape[0],
                        int(rSVM_gp_motpe.shape[0]/SVM_val_gp_motpe.shape[0]), 
                         SVM_val_gp_motpe.shape[1]))

# >>>>> DT
rDT_motpe = pd.read_csv("PF_data/ML/replications_MOTPE_DT.csv", sep=',', header=0).values[:,1:]
rDT_motpe = rDT_motpe.reshape((DT_val_motpe.shape[0],
                        int(rDT_motpe.shape[0]/DT_val_motpe.shape[0]), 
                         DT_val_motpe.shape[1]))

rDT_gp = pd.read_csv("PF_data/ML/replications_GP_DT.csv", sep=',', header=0).values[:,1:]
rDT_gp = rDT_gp.reshape((DT_val_gp.shape[0],
                        int(rDT_gp.shape[0]/DT_val_gp.shape[0]), 
                         DT_val_gp.shape[1]))

rDT_gp_motpe = pd.read_csv("PF_data/ML/replications_GP_MOTPE_DT.csv", sep=',', header=0).values[:,1:]
rDT_gp_motpe = rDT_gp_motpe.reshape((DT_val_gp_motpe.shape[0],
                        int(rDT_gp_motpe.shape[0]/DT_val_gp_motpe.shape[0]), 
                         DT_val_gp_motpe.shape[1]))

# %%
def plot_ML_exploration(file_name, model, initial_points, xlim=[0, 1], ylim=[0,1]):
    pf_model = pareto_front(model, index=True)
    pf_model = model[pf_model]


    fig, ax = plt.subplots(figsize=(8,8))
    ax.scatter(pf_model[:, 0], -pf_model[:, 1], s=50, label="Observed Pareto front", color='k')
    ax.scatter(model[initial_points:, 0], -model[initial_points:, 1], s=40, label="Infill points", marker='+', color='orange')
    ax.scatter(model[:initial_points, 0], -model[:initial_points, 1], s=40, label="Initial design", marker='+', color='blue')

    ax.set_xlabel("Error")
    ax.set_ylabel("Recall")
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.legend(loc='upper right')
    plt.savefig(file_name, dpi=1200, bbox_inches='tight')

# %%
# plot_ML_exploration("exploration_gp_MLP.pdf", ML_val_gp, 54, xlim=[0.05, 0.6], ylim=[0, 1])
# plot_ML_exploration("exploration_gp_SVM.pdf", SVM_val_gp, 21, xlim=[0.05, 0.8], ylim=[-0.02, .9])
plot_ML_exploration("exploration_gp_DT.pdf", DT_val_gp, 54, xlim=[0.1, 0.45], ylim=[0.2, .9])

# plot_ML_exploration("exploration_gp_motpe_ML.pdf", ML_val_gp_motpe, 54, xlim=[0.05, 0.6], ylim=[0, 1])
# plot_ML_exploration("exploration_gp_motpe_SVM.pdf", SVM_val_gp_motpe, 21, xlim=[0.05, 0.8], ylim=[-0.02, .9])
plot_ML_exploration("exploration_gp_motpe_DT.pdf", DT_val_gp_motpe, 54, xlim=[0.1, 0.45], ylim=[0.2, .9])

# plot_ML_exploration("exploration_motpe_ML.pdf", ML_val_motpe, 54, xlim=[0.05, 0.6], ylim=[0, 1])
# plot_ML_exploration("exploration_motpe_SVM.pdf", SVM_val_motpe, 21, xlim=[0.05, 0.8], ylim=[-0.02, .9])
plot_ML_exploration("exploration_motpe_DT.pdf", DT_val_motpe, 54, xlim=[0.1, 0.45], ylim=[0.2, .9])

# %%
def plot_ML_function(file_name, gp, motpe, gp_motpe):
    pf_gp = pareto_front(gp, index=True)
    pf_gp = gp[pf_gp]

    pf_motpe = pareto_front(motpe, index=True)
    pf_motpe = motpe[pf_motpe]

    pf_gp_motpe = pareto_front(gp_motpe, index=True)
    pf_gp_motpe = gp_motpe[pf_gp_motpe]


    fig, ax = plt.subplots(figsize=(10,10))
    ax.scatter(pf_gp[:, 0], -pf_gp[:, 1], s=50, label="Observed PF GP")
    ax.scatter(pf_motpe[:, 0], -pf_motpe[:, 1], s=50, label="Observed PF MOTPE")
    ax.scatter(pf_gp_motpe[:, 0], -pf_gp_motpe[:, 1], s=50, label="Observed PF GP_MOTPE")

    ax.set_xlabel("Error")
    ax.set_ylabel("Recall")
    # ax.set_xlim(xlim)
    # ax.set_ylim(ylim)
    ax.legend(loc='lower right')
    plt.savefig(file_name, dpi=1200, bbox_inches='tight')

# %%
plot_ML_function("pf_MLP.pdf", ML_val_gp, ML_val_motpe, ML_val_gp_motpe)
plot_ML_function("pf_SVM.pdf", SVM_val_gp, SVM_val_motpe, SVM_val_gp_motpe)
plot_ML_function("pf_DT.pdf", DT_val_gp, DT_val_motpe, DT_val_gp_motpe)

# %%
plot_hypervolumen("hv_MLP.pdf", 54, ML_val_gp, ML_val_motpe, ML_val_gp_motpe, [1, 0])
plot_hypervolumen("hv_SVM.pdf", 21, SVM_val_gp, SVM_val_motpe, SVM_val_gp_motpe, [1, 0])
plot_hypervolumen("hv_DT.pdf", 54, DT_val_gp, DT_val_motpe, DT_val_gp_motpe, [1, 0])
# Out:
# hv_MLP.pdf 0.8199371069182391 0.806203913169041 0.8128848992427161
# hv_SVM.pdf 0.7536891124374278 0.7544849826723142 0.7544849826723142
# hv_DT.pdf 0.766434547875754 0.7638189898600951 0.7601224971120524

# %%
# Overfitting analysis

def overfitting(ax, model_val, model_test, l, m, size, color):
    pf = pareto_front(model_val, index=True)
    pf_val = np.abs(model_val[pf]) # Compute the PF of the validation set
    pf_test = np.abs(model_test[pf]) # Select the evaluation on test set of those points that were dominant in validation set
    
    abs_dif = pf_val - pf_test
    distance = np.linalg.norm(abs_dif, axis=1)
#     print("distance", distance)
    print(">>", np.mean(distance))
    ax.scatter(abs_dif[:,0], abs_dif[:,1], label=l, s=size, marker=m, color=color)
    plt.xlabel("Error", loc='right')
    plt.ylabel("Recall", loc='top')
    
    return ax

# %%
def plot_overfitting(file_name, val_gp, test_gp, val_motpe, test_motpe, val_gp_motpe, test_gp_motpe, xlim, ylim):
    fig, ax = plt.subplots(figsize=(10,10))
    # Move left y-axis and bottim x-axis to centre, passing through (0,0)
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')

    # Eliminate upper and right axes
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # Show ticks in the left and lower axes only
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax = overfitting(ax, val_gp, test_gp, l="GP", m="s", size=100, color='blue')
    ax = overfitting(ax, val_motpe, test_motpe, l="MOTPE", m='o', size=90, color='orange')
    ax = overfitting(ax, val_gp_motpe, test_gp_motpe, l="GP_MOTPE", m='^', size=80, color='k')
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    plt.legend()
    plt.savefig(file_name, bbox_inches='tight')

# %%
plot_overfitting("overfitting_MLP.pdf", ML_val_gp, ML_test_gp, ML_val_motpe, ML_test_motpe, 
                 ML_val_gp_motpe, ML_test_gp_motpe, xlim=[-0.05, 0.05], ylim=[-0.1, 0.1])
plot_overfitting("overfitting_SVM.pdf", SVM_val_gp, SVM_test_gp, SVM_val_motpe, SVM_test_motpe, 
                 SVM_val_gp_motpe, SVM_test_gp_motpe,  xlim=[-0.01, 0.01], ylim=[-0.1, 0.1])
plot_overfitting("overfitting_DT.pdf", DT_val_gp, DT_test_gp, DT_val_motpe, DT_test_motpe, 
                 DT_val_gp_motpe, DT_test_gp_motpe,  xlim=[-0.05, 0.05], ylim=[-0.1, 0.1])
# Out:
# >> 0.03043070045804276
# >> 0.0401553939288513
# >> 0.028478309599030645
# >> 0.0020580724730424656
# >> 0.0012512685500133413
# >> 0.0013443650976656986
# >> 0.02936690451437253
# >> 0.04858099831322314
# >> 0.028622470116089267
